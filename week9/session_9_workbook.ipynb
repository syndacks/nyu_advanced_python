# %% [markdown]
# # Pandas 2 Homework Assignment

# %% [markdown]
# <U>Note on viewing large datasets</U>:  as you know, there are two ways to view a DataFrame in Jupyter Notebook:  by <B>print()</B>ing the DataFrame variable (i.e., <B>print(df)</B> (where <B>df</B> is the DataFrame), and by simply referring to the DataFrame variable as the last statement in a cell (i.e., <B>df</B> by itself on the last line), which displays a formatted view of the data with scrolling.  Note that either method may show an abbreviation of the data -- the text formatted view provided by Jupyter may include ellipses on large datasets -- so not all rows or columns may be displayed.

# %% [markdown]
# <B>3.1.</B> Open <B>govt_bond_feed_sample.xls</B>.  Look at the <B>len()</B> of the resulting dataframe -- make sure it is <B>102 rows</B> and that the data shows sovereign bond issues.  If it is not, make sure you are specifying the correct sheet name.  If you are unsure of the argument to use for sheet name, use <B>help(pd.read_excel)</B> to see the docstring.

# %%
import pandas as pd

df1 = pd.read_excel('govt_bond_feed_sample.xls')
print (len(df1))
df1.columns
# Out:
# 102
# Index(['Country has above $50 bil outstanding on 7/15?', 'LONG_COMP_NAME',
#        'CRNCY', 'Currency Type', 'ID_CUSIP', 'MARKET_SECTOR_DES',
#        'INDUSTRY_SECTOR', 'INDUSTRY_GROUP', 'INDUSTRY_SUBGROUP', 'COUNTRY',
#        'Eurozone?', 'COUNTRY_GUARANTOR', 'CNTRY_OF_DOMICILE', 'AMT_ISSUED',
#        'AMT_OUTSTANDING',
#        'Amount Outstanding (Stated Currency) from Market Value',
#        'Amount Outstanding (USD) from Market Value',
#        'Amount Outstanding (USD) from Market Value Fix', 'Yield at Issue Raw',
#        'Yield at Issue FIX', 'Price at Issue', 'ISSUE_DT', 'MATURITY',
#        'FINAL_MATURITY', 'Interest Payments from Current Coupons',
#        'Local Currency Rating'],
#       dtype='object')

# %% [markdown]
# <PRE><U>Expected Output</U>:
#
# 102</PRE>

# %% [markdown]
# <B>3.2.</B> Change all column headings so that they are UPPERCASE_WITH_UNDERSCORES.  Print <B>df.columns</B> to verify.

# %%
cols = df1.columns
cols = cols.map(lambda x: x.replace(' ', '_'))
cols = cols.map(lambda x: x.upper())
df1.columns = cols
df1.columns
# Out:
# Index(['COUNTRY_HAS_ABOVE_$50_BIL_OUTSTANDING_ON_7/15?', 'LONG_COMP_NAME',
#        'CRNCY', 'CURRENCY_TYPE', 'ID_CUSIP', 'MARKET_SECTOR_DES',
#        'INDUSTRY_SECTOR', 'INDUSTRY_GROUP', 'INDUSTRY_SUBGROUP', 'COUNTRY',
#        'EUROZONE?', 'COUNTRY_GUARANTOR', 'CNTRY_OF_DOMICILE', 'AMT_ISSUED',
#        'AMT_OUTSTANDING',
#        'AMOUNT_OUTSTANDING_(STATED_CURRENCY)_FROM_MARKET_VALUE',
#        'AMOUNT_OUTSTANDING_(USD)_FROM_MARKET_VALUE',
#        'AMOUNT_OUTSTANDING_(USD)_FROM_MARKET_VALUE_FIX', 'YIELD_AT_ISSUE_RAW',
#        'YIELD_AT_ISSUE_FIX', 'PRICE_AT_ISSUE', 'ISSUE_DT', 'MATURITY',
#        'FINAL_MATURITY', 'INTEREST_PAYMENTS_FROM_CURRENT_COUPONS',
#        'LOCAL_CURRENCY_RATING'],
#       dtype='object')

# %% [markdown]
# <PRE><U>Expected Output</U>:
#
# Index(['COUNTRY_HAS_ABOVE_$50_BIL_OUTSTANDING_ON_7/15?', 'LONG_COMP_NAME',
#        'CRNCY', 'CURRENCY_TYPE', 'ID_CUSIP',
#        'MARKET_SECTOR_DES', 'INDUSTRY_SECTOR', 'INDUSTRY_GROUP',
#        'INDUSTRY_SUBGROUP', 'COUNTRY', 'EUROZONE?', 'COUNTRY_GUARANTOR',
#        'CNTRY_OF_DOMICILE', 'AMT_ISSUED', 'AMT_OUTSTANDING',
#        'AMOUNT_OUTSTANDING_(STATED_CURRENCY)_FROM_MARKET_VALUE',
#        'AMOUNT_OUTSTANDING_(USD)_FROM_MARKET_VALUE',
#        'AMOUNT_OUTSTANDING_(USD)_FROM_MARKET_VALUE_FIX',
#        'YIELD_AT_ISSUE_RAW', 'YIELD_AT_ISSUE_FIX', 'PRICE_AT_ISSUE',
#        'ISSUE_DT', 'MATURITY', 'FINAL_MATURITY',
#        'INTEREST_PAYMENTS_FROM_CURRENT_COUPONS', 'LOCAL_CURRENCY_RATING'],
#       dtype='object')</PRE>

# %% [markdown]
# <B>3.3.</B>  <U>Limit columns to the following</U>:<BR>
# LONG_COMP_NAME <BR>
# CRNCY <BR>
# CURRENCY_TYPE <BR>
# ID_CUSIP <BR>
# COUNTRY <BR>
# EUROZONE? <BR>
# CNTRY_OF_DOMICILE <BR>
# AMT_ISSUED <BR>
# AMT_OUTSTANDING <BR>
# ISSUE_DT <BR>
# MATURITY <BR>
# LOCAL_CURRENCY\_RATING
#
# <U>Special note</U>:  Don't forget that <B>.loc[]</B> is the preferred way to select data that may later be changed.

# %%
columns_to_keep = [
    'LONG_COMP_NAME',
    'CRNCY',
    'CURRENCY_TYPE',
    'ID_CUSIP',
    'COUNTRY',
    'EUROZONE?',
    'CNTRY_OF_DOMICILE',
    'AMT_ISSUED',
    'AMT_OUTSTANDING',
    'ISSUE_DT',
    'MATURITY',
    'LOCAL_CURRENCY_RATING'
                  ]

for column in df1.columns:
    if column not in columns_to_keep:
        df1 = df1.drop(column, 1)

df1
# Out:
#                                         LONG_COMP_NAME CRNCY CURRENCY_TYPE  \
# 0              Abu Dhabi Government International Bond   USD       Foreign
# 1                               Angola Government Bond   AOA         Local
# 2                               Angola Government Bond   AOA         Local
# 3                               Angola Government Bond   AOA         Local
# 4                            Argentina Government Bond   USD       Foreign
# 5     Argentine Republic Government International Bond   USD       Foreign
# 6                  Bahamas Government Registered Stock   BSD         Local
# 7                             Bangladesh Treasury Bond   BDT         Local
# 8               Barbados Government International Bond   BBD         Local
# 9                              Bolivia Government Bond   BOB         Local
# 10               Bonos de la Tesoreria de la Republica   CLP         Local
# 11                  Kingdom of Belgium Government Bond   EUR         Local
# 12               Canadian Government Bond Coupon Strip   CAD         Local
# 13                                 United Kingdom Gilt   GBP         Local
# 14                Canadian When Issued Government Bond   CAD         Local
# 15                            Canadian Government Bond   CAD         Local
# 16                               China Government Bond   CNY         Local
# 17                     Costa Rica Titulos de Propiedad   CRC         Local
# 18                         Czech Republic Coupon Strip   CZK         Local
# 19               Deutsche Bundesrepublik Coupon Strips   EUR         Local
# 20                                Dutch Fungible Strip   EUR         Local
# 21                               Egypt Government Bond   EGP         Local
# 22          Federative Republic of Brazil Coupon Strip   USD       Foreign
# 23                                Fiji Government Bond   FJD         Local
# 24                             Finland Government Bond   EUR         Local
# 25   French Republic Government Bond OAT Fungible S...   EUR         Local
# 26                               Georgia Treasury Bond   GEL         Local
# 27                       Governo Portugues Consolidado   EUR         Local
# 28                          Bundesrepublik Deutschland   EUR         Local
# 29               Iceland Government International Bond   EUR       Foreign
# ..                                                 ...   ...           ...
# 72   Republic of Nicaragua Ministry of Finance & Pu...   USD       Foreign
# 73   Republic of Nicaragua Ministry of Finance & Pu...   USD       Foreign
# 74   Republic of Nicaragua Ministry of Finance & Pu...   USD       Foreign
# 75   Republic of Nicaragua Ministry of Finance & Pu...   USD       Foreign
# 76              Republic of Sierra Leone Treasury Bill   SLL         Local
# 77                     Republic of Turkey Coupon Strip   TRY         Local
# 78                     Republic of Turkey Coupon Strip   TRY         Local
# 79                   Republic of Zambia Treasury Bills   ZMW       Foreign
# 80                               Rwanda Treasury Bills   RWF         Local
# 81                               Serbia Treasury Bonds   EUR       Foreign
# 82                            Seychelles Treasury Bill   SCR         Local
# 83                                 Korea Treasury Bond   KRW         Local
# 84                          Sri Lanka Government Bonds   LKR         Local
# 85                            Sri Lanka Treasury Bills   LKR         Local
# 86                               Spain Government Bond   EUR         Local
# 87                              Taiwan Government Bond   TWD         Local
# 88                            Tanzania Government Bond   TZS         Local
# 89                   Trinidad & Tobago Government Bond   TTD         Local
# 90                             Ukraine Government Bond   UAH         Local
# 91                      Union of Myanmar Treasury Bond   MMK         Local
# 92                                 United Kingdom Gilt   GBP         Local
# 93              United Kingdom Gilt Coupon When Issued   GBP         Local
# 94                 United Kingdom Gilt Principal Strip   GBP         Local
# 95   United States Treasury Inflation Indexed Strip...   USD         Local
# 96              United States Treasury Strip Principal   USD         Local
# 97              United States Treasury Strip Principal   USD         Local
# 98   United States Treasury Inflation Indexed Strip...   USD         Local
# 99                    United States Treasury Note/Bond   USD         Local
# 100                            Vietnam Government Bond   VND         Local
# 101                             Zambia Government Bond   ZMW       Foreign
#
#      ID_CUSIP COUNTRY EUROZONE? CNTRY_OF_DOMICILE    AMT_ISSUED  \
# 0    LK401680      UA       Non                AE  1.500000e+09
# 1    JH363112      AO       Non                AO  5.138029e+09
# 2    CL987293      AO       Non                AO  1.452672e+10
# 3    EX517085      AO       Non                AO  7.744972e+09
# 4    EE909216      AR       Non                AR  2.608060e+09
# 5    GS622240      AR       Non                AR  1.188000e+09
# 6    WU319177      BH       Non                BS  1.500000e+07
# 7    QQ499387      BW       Non                BD  1.250000e+09
# 8    LW758746      BR       Non                BB  1.000000e+08
# 9    OK636078      BL       Non                BO  7.500000e+07
# 10   RV575081      CL       Non                CL  1.800000e+07
# 11   CQ972909      BE  Eurozone                BE  1.365200e+10
# 12   CP255124      CA       Non                CA           NaN
# 13   ZA529642      EN       Non                GB  2.734368e+10
# 14   BD509608      CA       Non                CA           NaN
# 15   RC141628      CA       Non                CA  1.150000e+10
# 16   CB172849      CH       Non                CN  2.800000e+10
# 17   ZK545000      CR       Non                CR  1.397278e+11
# 18   FJ828656      CZ       Non                CZ           NaN
# 19   QZ869039      GE  Eurozone                DE           NaN
# 20   QG306382      NE  Eurozone                NL           NaN
# 21   RV167734      EG       Non                EG  1.500000e+09
# 22   RT903035      BZ       Non                BR           NaN
# 23   OM794503      FJ       Non                FJ  1.400000e+07
# 24   MJ985169      FI  Eurozone                FI  4.000000e+09
# 25   XD115588      FR  Eurozone                FR           NaN
# 26   PN281751      GG       Non                GE  7.800000e+07
# 27   TI885603      PO  Eurozone                PT  1.542289e+07
# 28   EH500640      GE  Eurozone                DE  2.000000e+10
# 29   BE207697      IC       Non                IS  4.015000e+08
# ..        ...     ...       ...               ...           ...
# 72   CL831659      NC       Non                NI  5.803700e+02
# 73   SS877849      NC       Non                NI  1.120000e+05
# 74   OZ584851      NC       Non                NI  1.100000e+05
# 75   FN249257      NC       Non                NI  8.183000e+02
# 76   PV962004      S1       Non                SL  3.824095e+10
# 77   ZU948719      TU       Non                TR           NaN
# 78   IF243138      TU       Non                TR           NaN
# 79   JR952233      ZM       Non                ZM  8.237000e+07
# 80   IQ955487      RW       Non                RW  1.000000e+09
# 81   ID564864      RR       Non                RS  4.856800e+07
# 82   JC280491      SS       Non                SC  6.580000e+07
# 83   IV682880      SK       Non                KR  1.276306e+13
# 84   RG666954      SL       Non                LK  0.000000e+00
# 85   II660474      SL       Non                LK  1.000000e+09
# 86   MH173622      SP  Eurozone                ES  2.158229e+10
# 87   KW748932      TA       Non                TW  3.000000e+10
# 88   LC491871      TZ       Non                TZ  6.480530e+10
# 89   XG501594      TR       Non                TT  1.000000e+06
# 90   SE559258      UK       Non                UA  1.644780e+09
# 91   CL162028      MY       Non                MM  7.100000e+10
# 92   JX832598      EN       Non                GB  3.849288e+09
# 93   HF860297      EN       Non                GB           NaN
# 94   KF361365      EN       Non                GB           NaN
# 95   JH884199      US       Non                US  1.000000e+06
# 96   UG405648      US       Non                US  1.600000e+08
# 97   JO306918      US       Non                US           NaN
# 98   NP381903      US       Non                US  1.000000e+06
# 99   XP527352      US       Non                US  4.199900e+10
# 100  IR484228      VN       Non                VN  4.212000e+12
# 101  ES862725      ZM       Non                ZM  1.268000e+08
#
#      AMT_OUTSTANDING  ISSUE_DT    MATURITY LOCAL_CURRENCY_RATING
# 0       1.500000e+09  20090408  20190408.0                    NR
# 1       5.138029e+09  20121031  20171031.0                    B+
# 2       1.452672e+10  20160211  20210211.0                    B+
# 3       7.744972e+09  20160923  20180920.0                    B+
# 4       1.168280e+08  20010221  20060515.0                     B
# 5       0.000000e+00  20160422  20460422.0                     B
# 6       1.500000e+07  20060922  20240922.0                    NR
# 7       1.250000e+09  20100929  20300929.0                   BB-
# 8       1.000000e+08  20130501  20330731.0                    NR
# 9       7.500000e+07  20140418  20640216.0                    BB
# 10      1.800000e+07  20040916  20240801.0                   AA-
# 11      1.365200e+10  20130116  20230622.0                    AA
# 12      0.000000e+00            20531201.0                   AAA
# 13      2.734368e+10  20121024  20440122.0                    AA
# 14      0.000000e+00  20160118  20210301.0                   AAA
# 15      1.150000e+10  20100719  20210601.0                   AAA
# 16      2.800000e+10  20090611  20240611.0                    A+
# 17      1.397278e+11  20110601  20201223.0                   BB+
# 18      0.000000e+00  20071126  20281126.0                   AA-
# 19      0.000000e+00  20140228  20270815.0                   AAA
# 20      0.000000e+00  20160503  20300115.0                   AAA
# 21      1.500000e+09  20160809  20180206.0                     B
# 22      0.000000e+00  19940415  20171015.0                    BB
# 23      1.400000e+07  20160316  20310316.0                    NR
# 24      4.000000e+09  20160907  20230915.0                   AA+
# 25      0.000000e+00  20130404  20290525.0                    AA
# 26      7.800000e+07  20161006  20181006.0                   BB-
# 27      8.308890e+06  19420201         NaN                   BB+
# 28      2.000000e+10  20061117  20170104.0                   AAA
# 29      0.000000e+00  20100604  20250315.0                    A-
# ..               ...       ...         ...                   ...
# 72      5.803700e+02  20060201  20210201.0                    B+
# 73      6.720000e+04  20040201  20190201.0                    B+
# 74      4.400000e+04  20030201  20180201.0                    B+
# 75      8.183000e+02  20080201  20230201.0                    B+
# 76      3.824095e+10  20160707  20170706.0                    NR
# 77      0.000000e+00  20110119  20170111.0                   BBB
# 78      0.000000e+00  20131009  20230927.0                   BBB
# 79      8.237000e+07  20161003  20170102.0                     B
# 80      1.000000e+09  20160328  20170323.0                    B+
# 81      4.856800e+07  20140131  20190131.0                   BB-
# 82      6.580000e+07  20161005  20171005.0                    BB
# 83      8.614059e+12  20130910  20180910.0                    AA
# 84      0.000000e+00  20150702  20200601.0                    B+
# 85      1.000000e+09  20160909  20161209.0                    B+
# 86      2.158229e+10  20131126  20170430.0                  BBB+
# 87      0.000000e+00  20110513  20410222.0                   AA-
# 88      6.480530e+10  20130307  20200307.0                    NR
# 89      1.000000e+06  20100204  20290204.0                    NR
# 90      1.644780e+09  20131030  20181024.0                   CCC
# 91      7.100000e+10  20151115  20171115.0                   NaN
# 92      0.000000e+00  20121003  20220907.0                    AA
# 93      0.000000e+00  19990527  20250607.0                    AA
# 94      0.000000e+00  20120308  20170907.0                    AA
# 95      1.000000e+06  19990331  20171015.0                   AAA
# 96      1.600000e+08  20090515  20190515.0                   AAA
# 97      0.000000e+00  20110815  20210815.0                   AAA
# 98      1.000000e+06  20070131  20260715.0                   AAA
# 99      4.199900e+10  20130815  20430815.0                   AAA
# 100     4.212000e+12  20130630  20280630.0                   BB-
# 101     1.268000e+08  20140527  20190527.0                     B
#
# [102 rows x 12 columns]

# %% [markdown]
# <PRE><U>To verify expected output</U>:  display the dataframe in Jupyter by simply referring to it in the last line of a cell.  Scroll to the right to verify you have selected the correct columns.</PRE>

# %% [markdown]
# <B>3.4.</B>  Use <B>.isnull()</B> along with <B>.any()</B> on the DataFrame to see which columns contain any null values (<B>np.nan</B> or <B>NaN</B>).  You should see a list of columns along with <B>True/False</B> for each.

# %%
df1.isnull().any()
# Out:
# LONG_COMP_NAME           False
# CRNCY                    False
# CURRENCY_TYPE            False
# ID_CUSIP                 False
# COUNTRY                   True
# EUROZONE?                False
# CNTRY_OF_DOMICILE         True
# AMT_ISSUED                True
# AMT_OUTSTANDING          False
# ISSUE_DT                 False
# MATURITY                  True
# LOCAL_CURRENCY_RATING     True
# dtype: bool

# %% [markdown]
# <PRE><U>Expected Output</U>:
#
# LONG_COMP_NAME                False
# CRNCY                         False
# CURRENCY_TYPE                 False
# ID_CUSIP                      False
# COUNTRY                        True
# EUROZONE?                     False
# CNTRY_OF_DOMICILE              True
# <B>AMT_ISSUED                     True</B>
# AMT_OUTSTANDING               False
# ISSUE_DT                      False
# <B>MATURITY                       True</B>
# LOCAL_CURRENCY\_RATING     True
# dtype: bool</PRE>

# %% [markdown]
# <B>3.5.</B>  Fill in any missing values in <B>AMT_ISSUED</B> with 0.  <BR>
# Eliminate rows that do not have a value for <B>MATURITY</B>.
#
# Again <B>.isnull() with .any()</B> to confirm that <B>AMT_ISSUED</B> and <B>MATURITY</B> do not show any null values.

# %%
df1['AMT_ISSUED'] = df1['AMT_ISSUED'].fillna(0)
df1['MATURITY'] = df1['MATURITY'].fillna(0)

df1.isnull().any()
# Out:
# LONG_COMP_NAME           False
# CRNCY                    False
# CURRENCY_TYPE            False
# ID_CUSIP                 False
# COUNTRY                   True
# EUROZONE?                False
# CNTRY_OF_DOMICILE         True
# AMT_ISSUED               False
# AMT_OUTSTANDING          False
# ISSUE_DT                 False
# MATURITY                 False
# LOCAL_CURRENCY_RATING     True
# AMT_ISSUED_USD           False
# dtype: bool

# %% [markdown]
# <PRE><U>Expected Output</U>:
#
# LONG_COMP_NAME                False
# CRNCY                         False
# CURRENCY_TYPE                 False
# ID_CUSIP                      False
# COUNTRY                        True
# EUROZONE?                     False
# CNTRY_OF_DOMICILE              True
# <B>AMT_ISSUED                    False</B>
# AMT_OUTSTANDING               False
# ISSUE_DT                      False
# <B>MATURITY                      False</B>
# LOCAL_CURRENCY\_RATING         True
# dtype: bool</PRE>

# %% [markdown]
# <B>3.6.</B>  Display rows where <B>LOCAL_CURRENCY\_RATING</B> is <B>null</B> (you should see 2 rows); display rows where <B>COUNTRY</B> is <B>null</B> or <B>CNTRY_OF_DOMICILE</B> is <B>null</B> (you should see 1 row).

# %%
loc_cur_rat_null = df1['LOCAL_CURRENCY_RATING'].isnull()
df1[loc_cur_rat_null]


cntry_null_or_cntry_domic_null = df1['COUNTRY'].isnull() | df1['CNTRY_OF_DOMICILE'].isnull()
df1[cntry_null_or_cntry_domic_null]
# Out:
#             LONG_COMP_NAME CRNCY CURRENCY_TYPE  ID_CUSIP COUNTRY EUROZONE?  \
# 63  Namibia Treasury Bills   NAD         Local  SQ270103     NaN       Non
#
#    CNTRY_OF_DOMICILE   AMT_ISSUED  AMT_OUTSTANDING  ISSUE_DT    MATURITY  \
# 63               NaN  350000000.0      350000000.0  20160513  20170512.0
#
#    LOCAL_CURRENCY_RATING
# 63                   BBB

# %% [markdown]
# <PRE><U>To verify expected output</U>:  querying for "LOCAL_CURRENCY" rows should return <B>Niger Government Bond</B> and <B>Union of Myanmar Treasury Bond</B>.
#
# "COUNTRY" and "COUNTRY OF DOMICILE" should return one line, <B>Namibia Treasury Bills</B>.</PRE>

# %% [markdown]
# <B>3.7.</B>  Set column <B>ID_CUSIP</B> as the index for this DataFrame.    Print <B>df.index</B> to confirm.

# %%
df1.set_index('ID_CUSIP')
# Out:
#                                              LONG_COMP_NAME CRNCY  \
# ID_CUSIP
# LK401680            Abu Dhabi Government International Bond   USD
# JH363112                             Angola Government Bond   AOA
# CL987293                             Angola Government Bond   AOA
# EX517085                             Angola Government Bond   AOA
# EE909216                          Argentina Government Bond   USD
# GS622240   Argentine Republic Government International Bond   USD
# WU319177                Bahamas Government Registered Stock   BSD
# QQ499387                           Bangladesh Treasury Bond   BDT
# LW758746             Barbados Government International Bond   BBD
# OK636078                            Bolivia Government Bond   BOB
# RV575081              Bonos de la Tesoreria de la Republica   CLP
# CQ972909                 Kingdom of Belgium Government Bond   EUR
# CP255124              Canadian Government Bond Coupon Strip   CAD
# ZA529642                                United Kingdom Gilt   GBP
# BD509608               Canadian When Issued Government Bond   CAD
# RC141628                           Canadian Government Bond   CAD
# CB172849                              China Government Bond   CNY
# ZK545000                    Costa Rica Titulos de Propiedad   CRC
# FJ828656                        Czech Republic Coupon Strip   CZK
# QZ869039              Deutsche Bundesrepublik Coupon Strips   EUR
# QG306382                               Dutch Fungible Strip   EUR
# RV167734                              Egypt Government Bond   EGP
# RT903035         Federative Republic of Brazil Coupon Strip   USD
# OM794503                               Fiji Government Bond   FJD
# MJ985169                            Finland Government Bond   EUR
# XD115588  French Republic Government Bond OAT Fungible S...   EUR
# PN281751                              Georgia Treasury Bond   GEL
# TI885603                      Governo Portugues Consolidado   EUR
# EH500640                         Bundesrepublik Deutschland   EUR
# BE207697              Iceland Government International Bond   EUR
# ...                                                     ...   ...
# CL831659  Republic of Nicaragua Ministry of Finance & Pu...   USD
# SS877849  Republic of Nicaragua Ministry of Finance & Pu...   USD
# OZ584851  Republic of Nicaragua Ministry of Finance & Pu...   USD
# FN249257  Republic of Nicaragua Ministry of Finance & Pu...   USD
# PV962004             Republic of Sierra Leone Treasury Bill   SLL
# ZU948719                    Republic of Turkey Coupon Strip   TRY
# IF243138                    Republic of Turkey Coupon Strip   TRY
# JR952233                  Republic of Zambia Treasury Bills   ZMW
# IQ955487                              Rwanda Treasury Bills   RWF
# ID564864                              Serbia Treasury Bonds   EUR
# JC280491                           Seychelles Treasury Bill   SCR
# IV682880                                Korea Treasury Bond   KRW
# RG666954                         Sri Lanka Government Bonds   LKR
# II660474                           Sri Lanka Treasury Bills   LKR
# MH173622                              Spain Government Bond   EUR
# KW748932                             Taiwan Government Bond   TWD
# LC491871                           Tanzania Government Bond   TZS
# XG501594                  Trinidad & Tobago Government Bond   TTD
# SE559258                            Ukraine Government Bond   UAH
# CL162028                     Union of Myanmar Treasury Bond   MMK
# JX832598                                United Kingdom Gilt   GBP
# HF860297             United Kingdom Gilt Coupon When Issued   GBP
# KF361365                United Kingdom Gilt Principal Strip   GBP
# JH884199  United States Treasury Inflation Indexed Strip...   USD
# UG405648             United States Treasury Strip Principal   USD
# JO306918             United States Treasury Strip Principal   USD
# NP381903  United States Treasury Inflation Indexed Strip...   USD
# XP527352                   United States Treasury Note/Bond   USD
# IR484228                            Vietnam Government Bond   VND
# ES862725                             Zambia Government Bond   ZMW
#
#          CURRENCY_TYPE COUNTRY EUROZONE? CNTRY_OF_DOMICILE    AMT_ISSUED  \
# ID_CUSIP
# LK401680       Foreign      UA       Non                AE  1.500000e+09
# JH363112         Local      AO       Non                AO  5.138029e+09
# CL987293         Local      AO       Non                AO  1.452672e+10
# EX517085         Local      AO       Non                AO  7.744972e+09
# EE909216       Foreign      AR       Non                AR  2.608060e+09
# GS622240       Foreign      AR       Non                AR  1.188000e+09
# WU319177         Local      BH       Non                BS  1.500000e+07
# QQ499387         Local      BW       Non                BD  1.250000e+09
# LW758746         Local      BR       Non                BB  1.000000e+08
# OK636078         Local      BL       Non                BO  7.500000e+07
# RV575081         Local      CL       Non                CL  1.800000e+07
# CQ972909         Local      BE  Eurozone                BE  1.365200e+10
# CP255124         Local      CA       Non                CA  0.000000e+00
# ZA529642         Local      EN       Non                GB  2.734368e+10
# BD509608         Local      CA       Non                CA  0.000000e+00
# RC141628         Local      CA       Non                CA  1.150000e+10
# CB172849         Local      CH       Non                CN  2.800000e+10
# ZK545000         Local      CR       Non                CR  1.397278e+11
# FJ828656         Local      CZ       Non                CZ  0.000000e+00
# QZ869039         Local      GE  Eurozone                DE  0.000000e+00
# QG306382         Local      NE  Eurozone                NL  0.000000e+00
# RV167734         Local      EG       Non                EG  1.500000e+09
# RT903035       Foreign      BZ       Non                BR  0.000000e+00
# OM794503         Local      FJ       Non                FJ  1.400000e+07
# MJ985169         Local      FI  Eurozone                FI  4.000000e+09
# XD115588         Local      FR  Eurozone                FR  0.000000e+00
# PN281751         Local      GG       Non                GE  7.800000e+07
# TI885603         Local      PO  Eurozone                PT  1.542289e+07
# EH500640         Local      GE  Eurozone                DE  2.000000e+10
# BE207697       Foreign      IC       Non                IS  4.015000e+08
# ...                ...     ...       ...               ...           ...
# CL831659       Foreign      NC       Non                NI  5.803700e+02
# SS877849       Foreign      NC       Non                NI  1.120000e+05
# OZ584851       Foreign      NC       Non                NI  1.100000e+05
# FN249257       Foreign      NC       Non                NI  8.183000e+02
# PV962004         Local      S1       Non                SL  3.824095e+10
# ZU948719         Local      TU       Non                TR  0.000000e+00
# IF243138         Local      TU       Non                TR  0.000000e+00
# JR952233       Foreign      ZM       Non                ZM  8.237000e+07
# IQ955487         Local      RW       Non                RW  1.000000e+09
# ID564864       Foreign      RR       Non                RS  4.856800e+07
# JC280491         Local      SS       Non                SC  6.580000e+07
# IV682880         Local      SK       Non                KR  1.276306e+13
# RG666954         Local      SL       Non                LK  0.000000e+00
# II660474         Local      SL       Non                LK  1.000000e+09
# MH173622         Local      SP  Eurozone                ES  2.158229e+10
# KW748932         Local      TA       Non                TW  3.000000e+10
# LC491871         Local      TZ       Non                TZ  6.480530e+10
# XG501594         Local      TR       Non                TT  1.000000e+06
# SE559258         Local      UK       Non                UA  1.644780e+09
# CL162028         Local      MY       Non                MM  7.100000e+10
# JX832598         Local      EN       Non                GB  3.849288e+09
# HF860297         Local      EN       Non                GB  0.000000e+00
# KF361365         Local      EN       Non                GB  0.000000e+00
# JH884199         Local      US       Non                US  1.000000e+06
# UG405648         Local      US       Non                US  1.600000e+08
# JO306918         Local      US       Non                US  0.000000e+00
# NP381903         Local      US       Non                US  1.000000e+06
# XP527352         Local      US       Non                US  4.199900e+10
# IR484228         Local      VN       Non                VN  4.212000e+12
# ES862725       Foreign      ZM       Non                ZM  1.268000e+08
#
#           AMT_OUTSTANDING  ISSUE_DT    MATURITY LOCAL_CURRENCY_RATING
# ID_CUSIP
# LK401680     1.500000e+09  20090408  20190408.0                    NR
# JH363112     5.138029e+09  20121031  20171031.0                    B+
# CL987293     1.452672e+10  20160211  20210211.0                    B+
# EX517085     7.744972e+09  20160923  20180920.0                    B+
# EE909216     1.168280e+08  20010221  20060515.0                     B
# GS622240     0.000000e+00  20160422  20460422.0                     B
# WU319177     1.500000e+07  20060922  20240922.0                    NR
# QQ499387     1.250000e+09  20100929  20300929.0                   BB-
# LW758746     1.000000e+08  20130501  20330731.0                    NR
# OK636078     7.500000e+07  20140418  20640216.0                    BB
# RV575081     1.800000e+07  20040916  20240801.0                   AA-
# CQ972909     1.365200e+10  20130116  20230622.0                    AA
# CP255124     0.000000e+00            20531201.0                   AAA
# ZA529642     2.734368e+10  20121024  20440122.0                    AA
# BD509608     0.000000e+00  20160118  20210301.0                   AAA
# RC141628     1.150000e+10  20100719  20210601.0                   AAA
# CB172849     2.800000e+10  20090611  20240611.0                    A+
# ZK545000     1.397278e+11  20110601  20201223.0                   BB+
# FJ828656     0.000000e+00  20071126  20281126.0                   AA-
# QZ869039     0.000000e+00  20140228  20270815.0                   AAA
# QG306382     0.000000e+00  20160503  20300115.0                   AAA
# RV167734     1.500000e+09  20160809  20180206.0                     B
# RT903035     0.000000e+00  19940415  20171015.0                    BB
# OM794503     1.400000e+07  20160316  20310316.0                    NR
# MJ985169     4.000000e+09  20160907  20230915.0                   AA+
# XD115588     0.000000e+00  20130404  20290525.0                    AA
# PN281751     7.800000e+07  20161006  20181006.0                   BB-
# TI885603     8.308890e+06  19420201         NaN                   BB+
# EH500640     2.000000e+10  20061117  20170104.0                   AAA
# BE207697     0.000000e+00  20100604  20250315.0                    A-
# ...                   ...       ...         ...                   ...
# CL831659     5.803700e+02  20060201  20210201.0                    B+
# SS877849     6.720000e+04  20040201  20190201.0                    B+
# OZ584851     4.400000e+04  20030201  20180201.0                    B+
# FN249257     8.183000e+02  20080201  20230201.0                    B+
# PV962004     3.824095e+10  20160707  20170706.0                    NR
# ZU948719     0.000000e+00  20110119  20170111.0                   BBB
# IF243138     0.000000e+00  20131009  20230927.0                   BBB
# JR952233     8.237000e+07  20161003  20170102.0                     B
# IQ955487     1.000000e+09  20160328  20170323.0                    B+
# ID564864     4.856800e+07  20140131  20190131.0                   BB-
# JC280491     6.580000e+07  20161005  20171005.0                    BB
# IV682880     8.614059e+12  20130910  20180910.0                    AA
# RG666954     0.000000e+00  20150702  20200601.0                    B+
# II660474     1.000000e+09  20160909  20161209.0                    B+
# MH173622     2.158229e+10  20131126  20170430.0                  BBB+
# KW748932     0.000000e+00  20110513  20410222.0                   AA-
# LC491871     6.480530e+10  20130307  20200307.0                    NR
# XG501594     1.000000e+06  20100204  20290204.0                    NR
# SE559258     1.644780e+09  20131030  20181024.0                   CCC
# CL162028     7.100000e+10  20151115  20171115.0                   NaN
# JX832598     0.000000e+00  20121003  20220907.0                    AA
# HF860297     0.000000e+00  19990527  20250607.0                    AA
# KF361365     0.000000e+00  20120308  20170907.0                    AA
# JH884199     1.000000e+06  19990331  20171015.0                   AAA
# UG405648     1.600000e+08  20090515  20190515.0                   AAA
# JO306918     0.000000e+00  20110815  20210815.0                   AAA
# NP381903     1.000000e+06  20070131  20260715.0                   AAA
# XP527352     4.199900e+10  20130815  20430815.0                   AAA
# IR484228     4.212000e+12  20130630  20280630.0                   BB-
# ES862725     1.268000e+08  20140527  20190527.0                     B
#
# [102 rows x 11 columns]

# %% [markdown]
# <PRE><U>Expected Output</U>:
#
# Index(['29134UAB7', 'EK1898270', 'JK1313812', 'QZ6293943', 'EC3464624',
#        '040114GV6', 'EH6697161', 'EI7901354', 'EJ9077292', 'EK1869404',
#        ... continued ...
#        'EJ3796640', 'EC1377414', 'EJ3042904', '912833L32', '912820TQ0',
#        '912820YT8', '9128337B0', '912810RC4', 'EJ7621927', 'EK2699859'],
#       dtype='object', name='ID_CUSIP', length=101)</PRE>

# %% [markdown]
# <B>3.8.</B>  Reading the Currencies sheet from the DataFrame, create a dict or DataFrame lookup that matches the 'Currency' column to the 'USD Conversion' column.  Print the dict to confirm.

# %%
currencies = pd.read_excel('govt_bond_feed_sample.xls', sheetname='Currencies')
currency = currencies['Currency']
exchange_rate = currencies['USD Conversion']

lookup_dict = dict(zip(currency, exchange_rate))
lookup_dict
# Out:
# {'AED': 0.27229999999999999,
#  'AFN': 0.0150105,
#  'ALL': 0.0077999999999999996,
#  'AMD': 0.0020860000000000002,
#  'ANG': 0.56259999999999999,
#  'AOA': 0.0060000000000000001,
#  'ARS': 0.064299999999999996,
#  'ATS': 0.077100000000000002,
#  'AUD': 0.74829999999999997,
#  'AWG': 0.55869999999999997,
#  'AZN': 0.56040000000000001,
#  'BAM': 0.5423,
#  'BBD': 0.5,
#  'BDT': 0.012800000000000001,
#  'BEF': 0.0263,
#  'BGN': 0.54269999999999996,
#  'BHD': 2.6524000000000001,
#  'BIF': 0.00059480000000000004,
#  'BMD': 1.0,
#  'BND': 0.70179999999999998,
#  'BOB': 0.1444,
#  'BRL': 0.2954,
#  'BSD': 1.0,
#  'BWP': 0.093100000000000002,
#  'BYN': 0.5081,
#  'BYR': 5.0900000000000004e-05,
#  'CAD': 0.74570000000000003,
#  'CDF': 0.00089999999999999998,
#  'CHF': 0.98719999999999997,
#  'CLP': 0.0014815,
#  'CNY': 0.14463999999999999,
#  'COP': 0.00031828,
#  'CRC': 0.001812,
#  'CVE': 0.0096020000000000012,
#  'CZK': 0.039232000000000003,
#  'DEM': 0.54269999999999996,
#  'DKK': 0.14266999999999999,
#  'DOP': 0.021499999999999998,
#  'EEK': 0.067799999999999999,
#  'EGP': 0.0562,
#  'EUR': 1.0613999999999999,
#  'FJD': 0.47970000000000002,
#  'FRF': 0.1618,
#  'GBP': 1.2418,
#  'GEL': 0.39589999999999997,
#  'GHS': 0.23999999999999999,
#  'GMD': 0.023300000000000001,
#  'GTQ': 0.13300000000000001,
#  'HKD': 0.12892000000000001,
#  'HNL': 0.042900000000000001,
#  'HRK': 0.1409,
#  'HUF': 0.0034099999999999998,
#  'IDR': 7.3904000000000003e-05,
#  'ILS': 0.26034200000000002,
#  'INR': 0.014541999999999999,
#  'IQD': 0.00083099999999999992,
#  'ISK': 0.0088679999999999991,
#  'ITL': 0.00055000000000000003,
#  'JMD': 0.0077999999999999996,
#  'JOD': 1.4136,
#  'JPY': 0.0089350000000000002,
#  'KES': 0.0097999999999999997,
#  'KGS': 0.014500000000000001,
#  'KRW': 0.00085479999999999996,
#  'KWD': 3.2793999999999999,
#  'KZT': 0.0028999999999999998,
#  'LBP': 0.00066100000000000002,
#  'LKR': 0.0067390000000000002,
#  'LRD': 0.0118,
#  'LSL': 0.072914000000000007,
#  'LTL': 0.30740000000000001,
#  'LVL': 1.5103499999999999,
#  'MAD': 0.099299999999999999,
#  'MDL': 0.049456,
#  'MGA': 0.00030199999999999997,
#  'MKD': 0.017299999999999999,
#  'MMK': 0.00076000000000000004,
#  'MNT': 0.00040689999999999997,
#  'MRO': 0.0028020000000000002,
#  'MTL': 2.4722,
#  'MUR': 0.027739000000000003,
#  'MWK': 0.0013844,
#  'MXN': 0.048480000000000002,
#  'MYR': 0.224,
#  'MZN': 0.0134,
#  'NAD': 0.072914000000000007,
#  'NGN': 0.0031771999999999998,
#  'NLG': 0.48159999999999997,
#  'NOK': 0.1171,
#  'NPR': 0.0090919999999999994,
#  'NZD': 0.70740000000000003,
#  'OMR': 2.5973000000000002,
#  'PEN': 0.29267199999999999,
#  'PGK': 0.3155,
#  'PHP': 0.020101000000000001,
#  'PKR': 0.0095420000000000001,
#  'PLN': 0.24010000000000001,
#  'PYG': 0.00017150000000000002,
#  'QAR': 0.27460000000000001,
#  'RON': 0.2351,
#  'RSD': 0.0086,
#  'RUB': 0.01542,
#  'RWF': 0.0011999999999999999,
#  'SAR': 0.2666,
#  'SBD': 0.12790000000000001,
#  'SCR': 0.0746,
#  'SEK': 0.108696,
#  'SGD': 0.70230000000000004,
#  'SKK': 0.035235000000000002,
#  'SLL': 0.00020000000000000001,
#  'SZL': 0.072914000000000007,
#  'THB': 0.028132999999999998,
#  'TND': 0.43540000000000001,
#  'TOP': 0.4632,
#  'TRY': 0.29283999999999999,
#  'TTD': 0.1482,
#  'TWD': 0.031504999999999998,
#  'TZS': 0.00045900000000000004,
#  'UAH': 0.039,
#  'UGX': 0.00027599999999999999,
#  'USD': 1.0,
#  'UYI': 1.0,
#  'UYU': 0.034099999999999998,
#  'UZS': 0.00031500000000000001,
#  'VEB': 0.00010012999999999999,
#  'VEF': 0.10009999999999999,
#  'VND': 4.4022e-05,
#  'XAF': 0.0016130000000000001,
#  'XCD': 0.37040000000000001,
#  'XOF': 0.001614,
#  'YER': 0.0040000000000000001,
#  'ZAR': 0.072914000000000007,
#  'ZMK': 1.0,
#  'ZMW': 0.10100000000000001}

# %% [markdown]
# <PRE><U>Expected Output</U>:
#
# {'AED': 0.27229999999999999,
#  'AFN': 0.0150105,
#  'ALL': 0.0077999999999999996,
#  'AMD': 0.0020860000000000002,
#  'ANG': 0.56259999999999999,
#  'AOA': 0.0060000000000000001,
# ... continued ...
#
#  'XAF': 0.0016130000000000001,
#  'XCD': 0.37040000000000001,
#  'XOF': 0.001614,
#  'YER': 0.0040000000000000001,
#  'ZAR': 0.072914000000000007,
#  'ZMK': 1.0,
#  'ZMW': 0.10100000000000001}</PRE>

# %% [markdown]
# <B>3.9.</B>  Create a new column, <B>AMT_ISSUED_USD</B> to calculate <B>AMT_ISSUED</B> in dollars.  Use the currencies lookup you created in the prior step.  Print the first few rows of the below two columns to see the calculation.

# %%
df1['AMT_ISSUED_USD'] = (df1['AMT_ISSUED'] * df1['CRNCY'].apply(lambda x: lookup_dict[x]))
df1['AMT_ISSUED_USD']
df1[:4]
# Out:
#                             LONG_COMP_NAME CRNCY CURRENCY_TYPE  ID_CUSIP  \
# 0  Abu Dhabi Government International Bond   USD       Foreign  LK401680
# 1                   Angola Government Bond   AOA         Local  JH363112
# 2                   Angola Government Bond   AOA         Local  CL987293
# 3                   Angola Government Bond   AOA         Local  EX517085
#
#   COUNTRY EUROZONE? CNTRY_OF_DOMICILE    AMT_ISSUED  AMT_OUTSTANDING  \
# 0      UA       Non                AE  1.500000e+09     1.500000e+09
# 1      AO       Non                AO  5.138029e+09     5.138029e+09
# 2      AO       Non                AO  1.452672e+10     1.452672e+10
# 3      AO       Non                AO  7.744972e+09     7.744972e+09
#
#    ISSUE_DT    MATURITY LOCAL_CURRENCY_RATING  AMT_ISSUED_USD
# 0  20090408  20190408.0                    NR    1.500000e+09
# 1  20121031  20171031.0                    B+    3.082817e+07
# 2  20160211  20210211.0                    B+    8.716035e+07
# 3  20160923  20180920.0                    B+    4.646983e+07

# %% [markdown]
# <PRE><U>Expected Output</U>:
#                                               LONG_COMP_NAME  AMT_ISSUED_USD
# ID_CUSIP
# 29134UAB7            Abu Dhabi Government International Bond    1.500000e+09
# EK1898270                             Angola Government Bond    3.082817e+07
# JK1313812                             Angola Government Bond    8.716035e+07
# QZ6293943                             Angola Government Bond    4.646983e+07
# EC3464624                          Argentina Government Bond    2.608060e+09</PRE>

# %% [markdown]
# <B>3.10.</B>  Calculate average AMT_ISSUED by CRNCY.

# %%
df1['AMT_ISSUED'].groupby(df1['CRNCY']).mean()
# Out:
# CRNCY
# AOA    9.136575e+09
# BBD    1.000000e+08
# BDT    1.250000e+09
# BOB    7.500000e+07
# BSD    1.500000e+07
# CAD    3.833333e+09
# CLP    1.800000e+07
# CNY    2.800000e+10
# CRC    1.397278e+11
# CZK    0.000000e+00
# EGP    1.500000e+09
# EUR    3.994767e+09
# FJD    1.400000e+07
# GBP    7.798242e+09
# GEL    7.800000e+07
# HKD    1.300000e+09
# HUF    4.355284e+10
# INR    1.280000e+11
# JMD    3.000000e+09
# JOD    6.000000e+07
# JPY    1.283897e+12
# KRW    4.721853e+12
# KZT    5.634000e+10
# LBP    2.323750e+10
# LKR    5.000000e+08
# MDL    5.000000e+07
# MKD    2.518000e+08
# MMK    7.100000e+10
# MUR    4.540000e+09
# MXN    2.153279e+10
# MYR    7.000000e+09
# NAD    3.500000e+08
# NLG    1.000000e+09
# PHP    5.000000e+04
# PKR    0.000000e+00
# RWF    1.000000e+09
# SCR    6.580000e+07
# SLL    3.824095e+10
# TRY    0.000000e+00
# TTD    1.000000e+06
# TWD    3.000000e+10
# TZS    6.480530e+10
# UAH    1.644780e+09
# USD    2.970686e+09
# VND    4.212000e+12
# XOF    3.850000e+10
# ZMW    1.045850e+08
# Name: AMT_ISSUED, dtype: float64

# %% [markdown]
# <PRE><U>Expected Output</U>:
#
# CRNCY
# AOA    9.136575e+09
# BBD    1.000000e+08
# BDT    1.250000e+09
# BOB    7.500000e+07
# BSD    1.500000e+07
# CAD    1.150000e+10
# CLP    1.800000e+07
# CNY    2.800000e+10
# CRC    1.397278e+11
# ...continued...
#
# TZS    6.480530e+10
# UAH    1.644780e+09
# USD    3.564844e+09
# VND    4.212000e+12
# XOF    3.850000e+10
# ZMW    1.045850e+08
# Name: AMT_ISSUED, dtype: float64</PRE>

# %% [markdown]
# <B>3.11.</B>  Reading the "Country Codes" spreadsheet, build a new "Country Codes" dataframe with two columns named <B>COUNTRY</B> and <B>CTRY_NAME</B> from the 'Country Code' and 'Full Name' columns on the spreadsheet.

# %%
df_country_codes = pd.read_excel('govt_bond_feed_sample.xls', sheetname='Country Codes')

df_country_codes2 = df_country_codes.rename(columns={'Country Code':'COUNTRY', 'Full Name':'CTRY_NAME'})
df_country_codes2 = df_country_codes2.loc[:,['COUNTRY', 'CTRY_NAME']]
df_country_codes2
# Out:
#     COUNTRY        CTRY_NAME
# 0        US    United States
# 1        JN            Japan
# 2        CH            China
# 3        IT            Italy
# 4        FR           France
# 5        EN          Britain
# 6        GE          Germany
# 7        SP            Spain
# 8        IN            India
# 9        SK      South Korea
# 10       CA           Canada
# 11       BE          Belgium
# 12       NE      Netherlands
# 13       BZ           Brazil
# 14       AU        Australia
# 15       AS          Austria
# 16       MX           Mexico
# 17       EG            Egypt
# 18       MA         Malaysia
# 19       PO         Portugal
# 20       HK        Hong Kong
# 21       TA           Taiwan
# 22       ID        Indonesia
# 23       IR          Ireland
# 24       PD           Poland
# 25       TH         Thailand
# 26       DE          Denmark
# 27       SA     South Africa
# 28       FI          Finland
# 29       TU           Turkey
# ..      ...              ...
# 187      NC        Nicaragua
# 188      NK      North Korea
# 189      PS        Palestine
# 190      PN           Panama
# 191      PR      Puerto Rico
# 192      RO          Romania
# 193      WS     Samoa (West)
# 194      SM       San Marino
# 195      TM         Sao Tome
# 196      ZB          Seborga
# 197    SNAT             Snat
# 198      SQ             Snat
# 199      KI  St. Kitts & Nev
# 200      SD            Sudan
# 201      SU         Suriname
# 202      SY            Syria
# 203      RR           Serbia
# 204      TJ       Tajikistan
# 205      TO            Tonga
# 206      TT     Turkmenistan
# 207      TC   Turks & Caicos
# 208      TV           Tuvalu
# 209      UA              Uae
# 210      UZ       Uzbekistan
# 211      VA          Vanuatu
# 212      VC          Vatican
# 213      VG   Virgin Islands
# 214      YE            Yemen
# 215      ZI         Zimbabwe
# 216      ZM           Zambia
#
# [217 rows x 2 columns]

# %% [markdown]
# <PRE><U>Expected Output</U>:
#
#     COUNTRY        CTRY_NAME
# 0        US    United States
# 1        JN            Japan
# 2        CH            China
# 3        IT            Italy
# 4        FR           France
# 5        EN          Britain
# ... continued ...
# 211      VA          Vanuatu
# 212      VC          Vatican
# 213      VG   Virgin Islands
# 214      YE            Yemen
# 215      ZI         Zimbabwe
# 216      ZM           Zambia
#
# [217 rows x 2 columns]</PRE>

# %% [markdown]
# <B>3.12.</B>  Use a DataFrame <B>merge()</B> to do a LEFT merge/join of the Bond Feed DataFrame with the Country Codes DataFrame.  The CTRY_NAME field from Country Codes should appear as the rightmost column.

# %%
pd.merge(df1, df_country_codes2, on='COUNTRY', how='left')
# Out:
#                                         LONG_COMP_NAME CRNCY CURRENCY_TYPE  \
# 0              Abu Dhabi Government International Bond   USD       Foreign
# 1                               Angola Government Bond   AOA         Local
# 2                               Angola Government Bond   AOA         Local
# 3                               Angola Government Bond   AOA         Local
# 4                            Argentina Government Bond   USD       Foreign
# 5     Argentine Republic Government International Bond   USD       Foreign
# 6                  Bahamas Government Registered Stock   BSD         Local
# 7                             Bangladesh Treasury Bond   BDT         Local
# 8               Barbados Government International Bond   BBD         Local
# 9                              Bolivia Government Bond   BOB         Local
# 10               Bonos de la Tesoreria de la Republica   CLP         Local
# 11                  Kingdom of Belgium Government Bond   EUR         Local
# 12               Canadian Government Bond Coupon Strip   CAD         Local
# 13                                 United Kingdom Gilt   GBP         Local
# 14                Canadian When Issued Government Bond   CAD         Local
# 15                            Canadian Government Bond   CAD         Local
# 16                               China Government Bond   CNY         Local
# 17                     Costa Rica Titulos de Propiedad   CRC         Local
# 18                         Czech Republic Coupon Strip   CZK         Local
# 19               Deutsche Bundesrepublik Coupon Strips   EUR         Local
# 20                                Dutch Fungible Strip   EUR         Local
# 21                               Egypt Government Bond   EGP         Local
# 22          Federative Republic of Brazil Coupon Strip   USD       Foreign
# 23                                Fiji Government Bond   FJD         Local
# 24                             Finland Government Bond   EUR         Local
# 25   French Republic Government Bond OAT Fungible S...   EUR         Local
# 26                               Georgia Treasury Bond   GEL         Local
# 27                       Governo Portugues Consolidado   EUR         Local
# 28                          Bundesrepublik Deutschland   EUR         Local
# 29               Iceland Government International Bond   EUR       Foreign
# ..                                                 ...   ...           ...
# 72   Republic of Nicaragua Ministry of Finance & Pu...   USD       Foreign
# 73   Republic of Nicaragua Ministry of Finance & Pu...   USD       Foreign
# 74   Republic of Nicaragua Ministry of Finance & Pu...   USD       Foreign
# 75   Republic of Nicaragua Ministry of Finance & Pu...   USD       Foreign
# 76              Republic of Sierra Leone Treasury Bill   SLL         Local
# 77                     Republic of Turkey Coupon Strip   TRY         Local
# 78                     Republic of Turkey Coupon Strip   TRY         Local
# 79                   Republic of Zambia Treasury Bills   ZMW       Foreign
# 80                               Rwanda Treasury Bills   RWF         Local
# 81                               Serbia Treasury Bonds   EUR       Foreign
# 82                            Seychelles Treasury Bill   SCR         Local
# 83                                 Korea Treasury Bond   KRW         Local
# 84                          Sri Lanka Government Bonds   LKR         Local
# 85                            Sri Lanka Treasury Bills   LKR         Local
# 86                               Spain Government Bond   EUR         Local
# 87                              Taiwan Government Bond   TWD         Local
# 88                            Tanzania Government Bond   TZS         Local
# 89                   Trinidad & Tobago Government Bond   TTD         Local
# 90                             Ukraine Government Bond   UAH         Local
# 91                      Union of Myanmar Treasury Bond   MMK         Local
# 92                                 United Kingdom Gilt   GBP         Local
# 93              United Kingdom Gilt Coupon When Issued   GBP         Local
# 94                 United Kingdom Gilt Principal Strip   GBP         Local
# 95   United States Treasury Inflation Indexed Strip...   USD         Local
# 96              United States Treasury Strip Principal   USD         Local
# 97              United States Treasury Strip Principal   USD         Local
# 98   United States Treasury Inflation Indexed Strip...   USD         Local
# 99                    United States Treasury Note/Bond   USD         Local
# 100                            Vietnam Government Bond   VND         Local
# 101                             Zambia Government Bond   ZMW       Foreign
#
#      ID_CUSIP COUNTRY EUROZONE? CNTRY_OF_DOMICILE    AMT_ISSUED  \
# 0    LK401680      UA       Non                AE  1.500000e+09
# 1    JH363112      AO       Non                AO  5.138029e+09
# 2    CL987293      AO       Non                AO  1.452672e+10
# 3    EX517085      AO       Non                AO  7.744972e+09
# 4    EE909216      AR       Non                AR  2.608060e+09
# 5    GS622240      AR       Non                AR  1.188000e+09
# 6    WU319177      BH       Non                BS  1.500000e+07
# 7    QQ499387      BW       Non                BD  1.250000e+09
# 8    LW758746      BR       Non                BB  1.000000e+08
# 9    OK636078      BL       Non                BO  7.500000e+07
# 10   RV575081      CL       Non                CL  1.800000e+07
# 11   CQ972909      BE  Eurozone                BE  1.365200e+10
# 12   CP255124      CA       Non                CA  0.000000e+00
# 13   ZA529642      EN       Non                GB  2.734368e+10
# 14   BD509608      CA       Non                CA  0.000000e+00
# 15   RC141628      CA       Non                CA  1.150000e+10
# 16   CB172849      CH       Non                CN  2.800000e+10
# 17   ZK545000      CR       Non                CR  1.397278e+11
# 18   FJ828656      CZ       Non                CZ  0.000000e+00
# 19   QZ869039      GE  Eurozone                DE  0.000000e+00
# 20   QG306382      NE  Eurozone                NL  0.000000e+00
# 21   RV167734      EG       Non                EG  1.500000e+09
# 22   RT903035      BZ       Non                BR  0.000000e+00
# 23   OM794503      FJ       Non                FJ  1.400000e+07
# 24   MJ985169      FI  Eurozone                FI  4.000000e+09
# 25   XD115588      FR  Eurozone                FR  0.000000e+00
# 26   PN281751      GG       Non                GE  7.800000e+07
# 27   TI885603      PO  Eurozone                PT  1.542289e+07
# 28   EH500640      GE  Eurozone                DE  2.000000e+10
# 29   BE207697      IC       Non                IS  4.015000e+08
# ..        ...     ...       ...               ...           ...
# 72   CL831659      NC       Non                NI  5.803700e+02
# 73   SS877849      NC       Non                NI  1.120000e+05
# 74   OZ584851      NC       Non                NI  1.100000e+05
# 75   FN249257      NC       Non                NI  8.183000e+02
# 76   PV962004      S1       Non                SL  3.824095e+10
# 77   ZU948719      TU       Non                TR  0.000000e+00
# 78   IF243138      TU       Non                TR  0.000000e+00
# 79   JR952233      ZM       Non                ZM  8.237000e+07
# 80   IQ955487      RW       Non                RW  1.000000e+09
# 81   ID564864      RR       Non                RS  4.856800e+07
# 82   JC280491      SS       Non                SC  6.580000e+07
# 83   IV682880      SK       Non                KR  1.276306e+13
# 84   RG666954      SL       Non                LK  0.000000e+00
# 85   II660474      SL       Non                LK  1.000000e+09
# 86   MH173622      SP  Eurozone                ES  2.158229e+10
# 87   KW748932      TA       Non                TW  3.000000e+10
# 88   LC491871      TZ       Non                TZ  6.480530e+10
# 89   XG501594      TR       Non                TT  1.000000e+06
# 90   SE559258      UK       Non                UA  1.644780e+09
# 91   CL162028      MY       Non                MM  7.100000e+10
# 92   JX832598      EN       Non                GB  3.849288e+09
# 93   HF860297      EN       Non                GB  0.000000e+00
# 94   KF361365      EN       Non                GB  0.000000e+00
# 95   JH884199      US       Non                US  1.000000e+06
# 96   UG405648      US       Non                US  1.600000e+08
# 97   JO306918      US       Non                US  0.000000e+00
# 98   NP381903      US       Non                US  1.000000e+06
# 99   XP527352      US       Non                US  4.199900e+10
# 100  IR484228      VN       Non                VN  4.212000e+12
# 101  ES862725      ZM       Non                ZM  1.268000e+08
#
#      AMT_OUTSTANDING  ISSUE_DT    MATURITY LOCAL_CURRENCY_RATING  \
# 0       1.500000e+09  20090408  20190408.0                    NR
# 1       5.138029e+09  20121031  20171031.0                    B+
# 2       1.452672e+10  20160211  20210211.0                    B+
# 3       7.744972e+09  20160923  20180920.0                    B+
# 4       1.168280e+08  20010221  20060515.0                     B
# 5       0.000000e+00  20160422  20460422.0                     B
# 6       1.500000e+07  20060922  20240922.0                    NR
# 7       1.250000e+09  20100929  20300929.0                   BB-
# 8       1.000000e+08  20130501  20330731.0                    NR
# 9       7.500000e+07  20140418  20640216.0                    BB
# 10      1.800000e+07  20040916  20240801.0                   AA-
# 11      1.365200e+10  20130116  20230622.0                    AA
# 12      0.000000e+00            20531201.0                   AAA
# 13      2.734368e+10  20121024  20440122.0                    AA
# 14      0.000000e+00  20160118  20210301.0                   AAA
# 15      1.150000e+10  20100719  20210601.0                   AAA
# 16      2.800000e+10  20090611  20240611.0                    A+
# 17      1.397278e+11  20110601  20201223.0                   BB+
# 18      0.000000e+00  20071126  20281126.0                   AA-
# 19      0.000000e+00  20140228  20270815.0                   AAA
# 20      0.000000e+00  20160503  20300115.0                   AAA
# 21      1.500000e+09  20160809  20180206.0                     B
# 22      0.000000e+00  19940415  20171015.0                    BB
# 23      1.400000e+07  20160316  20310316.0                    NR
# 24      4.000000e+09  20160907  20230915.0                   AA+
# 25      0.000000e+00  20130404  20290525.0                    AA
# 26      7.800000e+07  20161006  20181006.0                   BB-
# 27      8.308890e+06  19420201         0.0                   BB+
# 28      2.000000e+10  20061117  20170104.0                   AAA
# 29      0.000000e+00  20100604  20250315.0                    A-
# ..               ...       ...         ...                   ...
# 72      5.803700e+02  20060201  20210201.0                    B+
# 73      6.720000e+04  20040201  20190201.0                    B+
# 74      4.400000e+04  20030201  20180201.0                    B+
# 75      8.183000e+02  20080201  20230201.0                    B+
# 76      3.824095e+10  20160707  20170706.0                    NR
# 77      0.000000e+00  20110119  20170111.0                   BBB
# 78      0.000000e+00  20131009  20230927.0                   BBB
# 79      8.237000e+07  20161003  20170102.0                     B
# 80      1.000000e+09  20160328  20170323.0                    B+
# 81      4.856800e+07  20140131  20190131.0                   BB-
# 82      6.580000e+07  20161005  20171005.0                    BB
# 83      8.614059e+12  20130910  20180910.0                    AA
# 84      0.000000e+00  20150702  20200601.0                    B+
# 85      1.000000e+09  20160909  20161209.0                    B+
# 86      2.158229e+10  20131126  20170430.0                  BBB+
# 87      0.000000e+00  20110513  20410222.0                   AA-
# 88      6.480530e+10  20130307  20200307.0                    NR
# 89      1.000000e+06  20100204  20290204.0                    NR
# 90      1.644780e+09  20131030  20181024.0                   CCC
# 91      7.100000e+10  20151115  20171115.0                   NaN
# 92      0.000000e+00  20121003  20220907.0                    AA
# 93      0.000000e+00  19990527  20250607.0                    AA
# 94      0.000000e+00  20120308  20170907.0                    AA
# 95      1.000000e+06  19990331  20171015.0                   AAA
# 96      1.600000e+08  20090515  20190515.0                   AAA
# 97      0.000000e+00  20110815  20210815.0                   AAA
# 98      1.000000e+06  20070131  20260715.0                   AAA
# 99      4.199900e+10  20130815  20430815.0                   AAA
# 100     4.212000e+12  20130630  20280630.0                   BB-
# 101     1.268000e+08  20140527  20190527.0                     B
#
#      AMT_ISSUED_USD          CTRY_NAME
# 0      1.500000e+09                Uae
# 1      3.082817e+07             Angola
# 2      8.716035e+07             Angola
# 3      4.646983e+07             Angola
# 4      2.608060e+09          Argentina
# 5      1.188000e+09          Argentina
# 6      1.500000e+07            Bahamas
# 7      1.600000e+07         Bangladesh
# 8      5.000000e+07           Barbados
# 9      1.083000e+07            Bolivia
# 10     2.666700e+04              Chile
# 11     1.449023e+10            Belgium
# 12     0.000000e+00             Canada
# 13     3.395538e+10            Britain
# 14     0.000000e+00             Canada
# 15     8.575550e+09             Canada
# 16     4.049920e+09              China
# 17     2.531867e+08         Costa Rica
# 18     0.000000e+00              Czech
# 19     0.000000e+00            Germany
# 20     0.000000e+00        Netherlands
# 21     8.430000e+07              Egypt
# 22     0.000000e+00             Brazil
# 23     6.715800e+06               Fiji
# 24     4.245600e+09            Finland
# 25     0.000000e+00             France
# 26     3.088020e+07            Georgia
# 27     1.636986e+07           Portugal
# 28     2.122800e+10            Germany
# 29     4.261521e+08            Iceland
# ..              ...                ...
# 72     5.803700e+02          Nicaragua
# 73     1.120000e+05          Nicaragua
# 74     1.100000e+05          Nicaragua
# 75     8.183000e+02          Nicaragua
# 76     7.648190e+06       Sierra Leone
# 77     0.000000e+00             Turkey
# 78     0.000000e+00             Turkey
# 79     8.319370e+06             Zambia
# 80     1.200000e+06             Rwanda
# 81     5.155008e+07             Serbia
# 82     4.908680e+06         Seychelles
# 83     1.090986e+10        South Korea
# 84     0.000000e+00          Sri Lanka
# 85     6.739000e+06          Sri Lanka
# 86     2.290744e+10              Spain
# 87     9.451500e+08             Taiwan
# 88     2.974563e+07           Tanzania
# 89     1.482000e+05  Trinidad & Tobago
# 90     6.414642e+07            Ukraine
# 91     5.396000e+07            Myanmar
# 92     4.780046e+09            Britain
# 93     0.000000e+00            Britain
# 94     0.000000e+00            Britain
# 95     1.000000e+06      United States
# 96     1.600000e+08      United States
# 97     0.000000e+00      United States
# 98     1.000000e+06      United States
# 99     4.199900e+10      United States
# 100    1.854207e+08            Vietnam
# 101    1.280680e+07             Zambia
#
# [102 rows x 14 columns]

# %% [markdown]
# <PRE><U>To verify expected output</U>:  viewing the merge, you should see the rightmost column <B>CTRY_NAME</B> with the correct full name for each country listed in <B>COUNTRY</B> ]</PRE>
